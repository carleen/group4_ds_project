# %%
import pandas as pd

# %% [markdown]
# Import the calendar .csv file and examine the different columns.

# %%
calendar = pd.read_csv('./primary/calendar.csv')
calendar.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 calendar = pd.read_csv('./primary/calendar.csv')
#       2 calendar.head()
#
# File /opt/anaconda3/envs/en685648/lib/python3.10/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/en685648/lib/python3.10/site-packages/pandas/util/_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# ...

# %% [markdown]
# "calendar" has a "listing_id" column, which is an id that maps to "id" in the "listings" and "listings-2" .csv files. To look at those next:

# %%
listings = pd.read_csv('./primary/listings.csv')
listings.head()
# Out:
#                    id                                      listing_url  \
# 0            22229408            https://www.airbnb.com/rooms/22229408
# 1            46951758            https://www.airbnb.com/rooms/46951758
# 2  580379638076900630  https://www.airbnb.com/rooms/580379638076900630
# 3  594971943284098653  https://www.airbnb.com/rooms/594971943284098653
# 4            54371126            https://www.airbnb.com/rooms/54371126
#
#         scrape_id last_scraped           source  \
# 0  20230319041206   2023-03-19  previous scrape
# 1  20230319041206   2023-03-19      city scrape
# 2  20230319041206   2023-03-19      city scrape
# 3  20230319041206   2023-03-19      city scrape
# 4  20230319041206   2023-03-19      city scrape
#
#                                                 name  \
# 0  Explorer's Paradise: Near Train, Bus & Bike Share
# 1  Boutique Style Home - Rooftop w/Breathtaking V...
# 2  Sojourn | Penthouse | Private Outdoor Space | ...
# ...

# %%
listings.columns.to_list()
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'source',
#  'name',
#  'description',
#  'neighborhood_overview',
#  'picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'latitude',
#  'longitude',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bathrooms_text',
#  'bedrooms',
#  'beds',
#  'amenities',
#  'price',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
# ...

# %%
listings_2 = pd.read_csv('./primary/listings-2.csv')
listings_2.head()
# Out:
#        id                                   name  host_id       host_name  \
# 0    3686                        Vita's Hideaway     4645            Vita
# 1  871825         Prime location on Capitol Hill  4597024  Rich And Betsy
# 2  116951    Upscale Private Close to Everything   481929           Chris
# 3  150109    Great apartment in perfect location   723470       Steffanie
# 4  153545  Guest Room 3 miles to the White House   738459         Natasha
#
#    neighbourhood_group                                   neighbourhood  \
# 0                  NaN                              Historic Anacostia
# 1                  NaN                      Capitol Hill, Lincoln Park
# 2                  NaN  Howard University, Le Droit Park, Cardozo/Shaw
# 3                  NaN      Dupont Circle, Connecticut Avenue/K Street
# 4                  NaN            Brightwood Park, Crestwood, Petworth
#
#     latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
listings_2.columns.to_list()
# Out:
# ['id',
#  'name',
#  'host_id',
#  'host_name',
#  'neighbourhood_group',
#  'neighbourhood',
#  'latitude',
#  'longitude',
#  'room_type',
#  'price',
#  'minimum_nights',
#  'number_of_reviews',
#  'last_review',
#  'reviews_per_month',
#  'calculated_host_listings_count',
#  'availability_365',
#  'number_of_reviews_ltm',
#  'license']

# %%
neighborhoods = pd.read_csv('./primary/neighbourhoods.csv')
neighborhoods.head()
# Out:
#    neighbourhood_group                                    neighbourhood
# 0                  NaN             Brightwood Park, Crestwood, Petworth
# 1                  NaN                    Brookland, Brentwood, Langdon
# 2                  NaN                       Capitol Hill, Lincoln Park
# 3                  NaN  Capitol View, Marshall Heights, Benning Heights
# 4                  NaN   Cathedral Heights, McLean Gardens, Glover Park

# %%
reviews = pd.read_csv('./primary/reviews.csv')
reviews.head()
# Out:
#    listing_id      id        date  reviewer_id reviewer_name  \
# 0        3686  131293  2010-11-01       257234        Callie
# 1        3686  150766  2010-12-08       255888       Patrick
# 2        3686  177749  2011-02-02       366688      Benjamin
# 3        3686  197451  2011-03-12       213492          T.J.
# 4        3686  213212  2011-03-30       428455          Pete
#
#                                             comments
# 0  Staying with Levita and her wonderful family w...
# 1  Vita is a very welcoming, helpful and friendly...
# 2  This was my first time using "airbnb" and it m...
# 3  First, Vita saved my work week by providing me...
# 4  Great host! Very welcoming and organised. I st...

# %% [markdown]
# "reviews" also contains a listing id, along with its own unique id.

# %%
reviews_2 = pd.read_csv('./primary/reviews-2.csv')
reviews_2.head()
# Out:
#    listing_id        date
# 0        3686  2010-11-01
# 1        3686  2010-12-08
# 2        3686  2011-02-02
# 3        3686  2011-03-12
# 4        3686  2011-03-30
